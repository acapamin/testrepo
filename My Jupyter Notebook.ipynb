# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Asyraf Amin**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I aspire to solve climate disaster using Data Science and AI*

# %% [markdown]
# ### This is the first line of code that every python student executes in their first lesson!

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# * Discover the **world!**
#
# ![alt text](https://openthread.google.cn/images/ot-contrib-google.png "Logo Title Text 1")
#
# [Click here to find any information in the world!](https://www.google.com)
